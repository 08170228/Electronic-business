# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
rs = pd.read_excel('erro.xlsx')
rs
# Out:
#         electricHeating_1  electricHeating_2  electricHeating_3  \
# 0                   465.0              534.9              535.1
# 1                   464.9              534.6              535.5
# 2                   465.0              534.8              535.0
# 3                   465.1              535.0              535.5
# 4                   464.8              534.9              534.8
# ...                   ...                ...                ...
# 312236              440.2              560.1              560.2
# 312237              440.0              560.0              560.0
# 312238              439.8              560.0              560.0
# 312239              440.0              560.1              559.9
# 312240              440.1              559.7              559.9
#
#         electricHeating_4  electricHeating_5  electricHeating_6  \
# 0                   405.1              464.9              464.9
# 1                   404.9              465.0              465.3
# 2                   404.9              464.9              464.9
# 3                   405.1              465.1              465.1
# 4                   405.0              465.0              465.1
# ...                   ...                ...                ...
# 312236              439.9              460.2              460.0
# 312237              440.0              460.1              459.9
# 312238              439.9              459.9              459.9
# 312239              440.0              460.1              460.0
# 312240              440.1              460.2              459.9
#
#         electricHeating_7  electricHeating_8  electricHeating_9  \
# 0                   465.1              404.9              529.8
# 1                   465.2              404.9              532.2
# 2                   465.0              404.8              528.9
# 3                   465.0              404.9              530.3
# 4                   465.1              405.0              528.6
# ...                   ...                ...                ...
# 312236              460.1              440.1              560.6
# 312237              460.0              440.2              559.4
# 312238              460.2              439.8              560.3
# 312239              460.0              440.0              558.7
# 312240              460.1              440.0              560.5
#
#         electricHeating_10  ...  electricHeating_79  electricHeating_80  \
# 0                    533.5  ...               435.0               434.8
# 1                    536.3  ...               435.0               435.0
# 2                    534.0  ...               434.9               434.9
# 3                    533.5  ...               435.0               435.0
# 4                    535.9  ...               435.1               435.2
# ...                    ...  ...                 ...                 ...
# 312236               560.1  ...               350.1               350.2
# 312237               559.6  ...               349.7               349.8
# 312238               560.4  ...               350.2               350.2
# 312239               559.5  ...               350.0               350.1
# 312240               560.3  ...               350.2               349.9
#
#         electricHeating_81  electricHeating_82  electricHeating_83  \
# 0                    435.0               218.1               239.6
# 1                    435.3               217.9               239.6
# 2                    435.0               217.7               239.3
# 3                    435.1               218.1               239.2
# 4                    434.9               218.0               239.4
# ...                    ...                 ...                 ...
# 312236               350.1               350.0               350.1
# 312237               350.0               350.3               350.0
# 312238               350.1               350.0               350.0
# 312239               350.0               350.1               350.1
# 312240               350.2               350.2               350.2
#
#         electricHeating_84  electricHeating_85  electricHeating_86  \
# 0                    229.9                61.4                53.5
# 1                    229.7                61.3                53.4
# 2                    229.6                61.2                53.4
# 3                    229.6                61.3                53.4
# 4                    229.5                61.3                53.2
# ...                    ...                 ...                 ...
# 312236               350.0                44.4                43.0
# 312237               350.0                44.4                43.0
# 312238               350.2                44.4                43.1
# 312239               350.0                44.4                43.1
# 312240               350.0                44.4                43.0
#
#         electricHeating_87  erro
# 0                     60.7     0
# 1                     60.5     0
# 2                     60.5     0
# 3                     60.4     0
# 4                     60.3     0
# ...                    ...   ...
# 312236                45.2     0
# 312237                45.1     0
# 312238                45.1     0
# 312239                45.1     0
# 312240                45.0     0
#
# [312241 rows x 87 columns]

# %%
rs1 = rs[rs["erro"]==1]
rs0 = rs[rs["erro"]==0]

# %%
Sp1 = rs0[['electricHeating_9', 'electricHeating_10', 'electricHeating_11', 'electricHeating_12',
           'electricHeating_44', 'electricHeating_45', 'electricHeating_46', 'electricHeating_47',
           'electricHeating_48', 'electricHeating_49', 'electricHeating_50', 'electricHeating_51',
           'electricHeating_52', 'electricHeating_53', 'electricHeating_54', 'electricHeating_55',
           'electricHeating_83', 'electricHeating_84', 'electricHeating_85', 'electricHeating_86',
           'electricHeating_87', 'erro']].sample(n=9986,axis=0)
a = pd.concat([rs1[['electricHeating_9', 'electricHeating_10', 'electricHeating_11', 'electricHeating_12',
           'electricHeating_44', 'electricHeating_45', 'electricHeating_46', 'electricHeating_47',
           'electricHeating_48', 'electricHeating_49', 'electricHeating_50', 'electricHeating_51',
           'electricHeating_52', 'electricHeating_53', 'electricHeating_54', 'electricHeating_55',
           'electricHeating_83', 'electricHeating_84', 'electricHeating_85', 'electricHeating_86',
           'electricHeating_87', 'erro']],Sp1])
a
# Out:
#         electricHeating_9  electricHeating_10  electricHeating_11  \
# 7774                536.4               558.3               555.8
# 18547               521.0               520.8               539.7
# 20798               519.6               515.3               540.1
# 28033               563.2               566.3               573.7
# 47055               490.4               136.5               157.9
# ...                   ...                 ...                 ...
# 159126              519.9               528.4               579.3
# 209128              519.3               518.7               539.0
# 225642              507.8               508.4               538.7
# 264269              559.3               569.1               569.8
# 282788              519.8               550.1               549.8
#
#         electricHeating_12  electricHeating_44  electricHeating_45  \
# 7774                 559.8               134.2               157.9
# 18547                539.5               479.4               479.4
# 20798                537.7               480.1               479.8
# 28033                573.4               579.9               549.7
# 47055                490.5               319.6               319.6
# ...                    ...                 ...                 ...
# 159126               569.0               570.4               569.9
# 209128               538.8               389.9               389.5
# 225642               528.7               479.7               459.8
# 264269               559.7                97.1                98.4
# 282788               539.9               102.4               100.1
#
#         electricHeating_46  electricHeating_47  electricHeating_48  \
# 7774                 147.1               101.6               111.4
# 18547                479.5               489.6               489.4
# 20798                480.0               490.0               489.7
# 28033                569.6               121.8               109.4
# 47055                319.9               320.1               319.8
# ...                    ...                 ...                 ...
# 159126               580.0               128.4               118.3
# 209128               389.9               399.7               389.3
# 225642               499.8               499.9               499.8
# 264269               102.8                76.3                70.8
# 282788               107.2                74.6                68.6
#
#         electricHeating_49  ...  electricHeating_52  electricHeating_53  \
# 7774                 109.0  ...                90.2                62.0
# 18547                489.5  ...               115.6                70.6
# 20798                489.9  ...               104.0                69.1
# 28033                111.8  ...                85.0                60.9
# 47055                319.9  ...               319.7               309.9
# ...                    ...  ...                 ...                 ...
# 159126               123.6  ...                96.5                68.4
# 209128               399.9  ...               399.7               420.0
# 225642               499.9  ...               116.5                82.0
# 264269                76.4  ...                67.1                52.5
# 282788                77.2  ...                64.1                46.9
#
#         electricHeating_54  electricHeating_55  electricHeating_83  \
# 7774                  67.2                70.8               379.3
# 18547                 73.7                84.1               222.6
# 20798                 64.3                74.6               225.5
# 28033                 59.5                65.7               439.6
# 47055                319.7               319.8               289.5
# ...                    ...                 ...                 ...
# 159126                67.7                77.1               410.1
# 209128               419.5               419.7               420.0
# 225642                70.4                84.3               238.5
# 264269                51.9                57.0               350.0
# 282788                45.9                52.3               330.0
#
#         electricHeating_84  electricHeating_85  electricHeating_86  \
# 7774                 379.4                54.6                60.5
# 18547                218.2                60.8                64.9
# 20798                215.8                60.1                56.8
# 28033                439.7                56.3                56.4
# 47055                349.5                93.6               110.1
# ...                    ...                 ...                 ...
# 159126               410.2                63.4                64.1
# 209128               419.6               105.2               115.1
# 225642               234.4                69.9                62.8
# 264269               380.1                49.5                51.7
# 282788               330.3                44.1                43.2
#
#         electricHeating_87  erro
# 7774                  58.3     1
# 18547                 68.1     1
# 20798                 60.6     1
# 28033                 57.3     1
# 47055                103.3     1
# ...                    ...   ...
# 159126                65.8     0
# 209128               110.0     0
# 225642                68.5     0
# 264269                51.1     0
# 282788                45.4     0
#
# [10000 rows x 22 columns]

# %%
x0, y0 = rs['electricHeating_9'], rs['erro']

# %%
import numpy as np
np.polyfit(x=rs['electricHeating_9'] , y=rs['erro'], deg=1)
# Out:
# array([4.97960793e-08, 1.83305208e-05])

# %%
y_pred = rs['electricHeating_9'].values * 1.79308120e-06 + (4.47120879e-04)

# %%
plt.figure(figsize=(6, 4))
plt.scatter(x=x0 , y=y0, color='black')
plt.plot(x0 , y_pred, color='red')
plt.show()

# %%
X = a.iloc[:, :-1].values
y = a.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
X_train, X_test, y_train, y_test
# Out:
# (array([[549.7, 549.7, 549.7, ...,  47.8,  46.7,  49.1],
#         [553.2, 557.8, 576.3, ...,  61.4,  60.5,  62.3],
#         [490. , 490. , 539.3, ...,  71.4,  74.2,  71.5],
#         ...,
#         [525.5, 539.8, 539. , ...,  67. ,  58.5,  63.9],
#         [521.1, 521.8, 582.2, ...,  62.2,  62.1,  64.2],
#         [558.5, 559.2, 578.2, ...,  63.5,  63.3,  63.6]]),
#  array([[566.1, 565.5, 577.2, ...,  61.9,  63.8,  61.5],
#         [527.3, 144.3, 168.4, ..., 103.7, 107.1, 109.7],
#         [530. , 531.5, 539.8, ...,  66.7,  58.6,  64.8],
#         ...,
#         [520.2, 520.4, 540.3, ...,  67.7,  58.7,  64.4],
#         [518.7, 518.4, 507.9, ...,  97.4,  93.2,  96.2],
#         [557.5, 300.4, 300.3, ...,  64.5,  56.9,  61.6]]),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Accuracy: {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
disp.plot()
plt.show()

from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier, X = sc.fit_transform(X), y = y, cv = 10)
print(accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# [[2499    0]
#  [   1    0]]
# Accuracy: 99.96 %
# [0.998 0.998 0.998 0.998 0.999 0.999 0.999 0.999 0.999 0.999]
# Accuracy: 99.86 %
# Standard Deviation: 0.05 %

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100, criterion='entropy', random_state=0)
classifier.fit(X_train,y_train)

y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Test Sets Accuracy: {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
disp.plot()
plt.show()

accuracies = cross_val_score(estimator=classifier, X = sc.fit_transform(X), y = y, cv = 10)
print(accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# [[2499    0]
#  [   1    0]]
# Test Sets Accuracy: 99.96 %
# [0.998 0.998 0.998 0.998 0.999 0.999 0.999 0.999 0.999 0.999]
# Accuracy: 99.86 %
# Standard Deviation: 0.05 %
